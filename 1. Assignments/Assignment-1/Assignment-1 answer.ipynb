# %% [markdown]
# # Task1-Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
import numpy as np
import pandas as pd

random_data = np.random.randn(4, 4)


random_data
# Out:
# array([[-0.21510709,  0.83035518,  1.18989368,  0.1982141 ],
#        [-0.4729894 , -1.10526702, -1.02676397, -3.05274003],
#        [ 1.50685417, -0.13387163,  1.40280283, -1.66245167],
#        [ 1.40272775, -0.07964331,  0.56728214, -0.98999966]])

# %% [markdown]
# # Task - 2 Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
df = pd.DataFrame(random_data, columns=['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4'])
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0       -0.215107        0.830355        1.189894        0.198214
# 1       -0.472989       -1.105267       -1.026764       -3.052740
# 2        1.506854       -0.133872        1.402803       -1.662452
# 3        1.402728       -0.079643        0.567282       -0.990000

# %% [markdown]
# # Task - 3 Find the descriptive statistics of the 'df' dataframe.

# %%
ds=df.describe()
ds
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.555371       -0.122107        0.533304       -1.376744
# std          1.044748        0.790723        1.098803        1.356547
# min         -0.472989       -1.105267       -1.026764       -3.052740
# 25%         -0.279578       -0.376720        0.168771       -2.010024
# 50%          0.593810       -0.106757        0.878588       -1.326226
# 75%          1.428759        0.147856        1.243121       -0.692946
# max          1.506854        0.830355        1.402803        0.198214

# %% [markdown]
# # Task - 4 Check for the null values in 'df' and find the data type of the columns.

# %%
nullvalues=df.isnull().sum()
nullvalues
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %% [markdown]
# # Task - 5 Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
new_values=df.iloc[:, [1, 2]]
new_values
# Out:
#    Random value 2  Random value 3
# 0        0.830355        1.189894
# 1       -1.105267       -1.026764
# 2       -0.133872        1.402803
# 3       -0.079643        0.567282
